# %% [markdown]
# #### 1. Import pandas library

# %%
import pandas as pd

# %% [markdown]
# #### 2. Import mysql.connector

# %%
import mysql.connector

# %% [markdown]
# #### 2.2. Run the following line

# %%
cnx = mysql.connector.connect(user='guest', password='relational', host='relational.fit.cvut.cz', database='stats', use_pure=True)

# %% [markdown]
# ### Import users table:

# %% [markdown]
# #### 3. Initialize cursor (as seen in classes' Jupyter Notebook)

# %%
cursor = cnx.cursor()

# %% [markdown]
# #### 4. Initialize query  (as seen in classes' Jupyter Notebook)
# #### You want the users table from stats database. (Hint: stats.users)

# %%
query = ("SELECT * FROM stats.users")

# %% [markdown]
# #### 5. Send query to database  (as seen in classes' Jupyter Notebook)

# %%
cursor.execute(query)

# %%
cursor

# %% [markdown]
# #### 6. Create a new dataframe (preferably called users) with the following columns names (as seen in classes' Jupyter Notebook)

# %%
columns_users = ['userId', 'Reputation', 'CreationDate', 'DisplayName', 'LastAccessDate', 'WebsiteUrl', 'Location', 'AboutMe', 'Views', 'UpVotes', 'DownVotes', 'AccountId', 'Age', 'ProfileImageUrl']
users = pd.DataFrame(columns = columns_users)

users
# Out:
# Empty DataFrame
# Columns: [userId, Reputation, CreationDate, DisplayName, LastAccessDate, WebsiteUrl, Location, AboutMe, Views, UpVotes, DownVotes, AccountId, Age, ProfileImageUrl]
# Index: []

# %% [markdown]
# #### 7. Fill the new users dataframe with the data you can get iterating through cursor (as seen in classes' Jupyter Notebook)

# %%
#for i, data in enumerate(cursor):
    #users.loc[i] = data

# %%
users = pd.read_csv('users_table.csv')

# %%
users.columns = columns_users

# %%
users.head()
# Out:
#    userId  Reputation         CreationDate   DisplayName       LastAccessDate  \
# 0       1           1  2010-07-19 06:55:26     Community  2010-07-19 06:55:26
# 1       2         101  2010-07-19 14:01:36  Geoff Dalgas  2013-11-12 22:07:23
# 2       3         101  2010-07-19 15:34:50  Jarrod Dixon  2014-08-08 06:42:58
# 3       4         101  2010-07-19 19:03:27        Emmett  2014-01-02 09:31:02
# 4       5        6792  2010-07-19 19:03:57         Shane  2014-08-13 00:23:47
#
#                        WebsiteUrl            Location  \
# 0  http://meta.stackexchange.com/  on the server farm
# 1        http://stackoverflow.com       Corvallis, OR
# 2        http://stackoverflow.com        New York, NY
# 3    http://minesweeperonline.com   San Francisco, CA
# 4         http://www.statalgo.com        New York, NY
#
#                                              AboutMe  Views  UpVotes  \
# 0  <p>Hi, I'm not really a person.</p>\n\n<p>I'm ...      0     5007
# ...

# %% [markdown]
# #### 8. Rename Id column to userId

# %%
#??

# %% [markdown]
# ### Import posts table:

# %% [markdown]
# #### 9. Initialize cursor (as seen in classes' Jupyter Notebook)

# %%
cnx = mysql.connector.connect(user='guest', password='relational', host='relational.fit.cvut.cz', database='stats', use_pure=True)
cursor = cnx.cursor()

# %% [markdown]
# #### 10. Initialize query  (as seen in classes' Jupyter Notebook)
# #### You want the posts table from stats database. (Hint: no hint this time ;) )

# %%
query = ("SELECT * FROM stats.posts")

# %% [markdown]
# #### 11. Send query to database  (as seen in classes' Jupyter Notebook)

# %%
cursor.execute(query)

# %% [markdown]
# #### 12. Create a new dataframe (preferably called posts) with the following columns names (as seen in classes' Jupyter Notebook)

# %%
columns_posts = ['Id', 'PostTypeId', 'AcceptedAnswerId', 'CreaionDate', 'Score', 'ViewCount', 'Body', 'OwnerUserId', 'LasActivityDate', 'Title', 'Tags', 'AnswerCount', 'CommentCount', 'FavoriteCount', 'LastEditorUserId', 'LastEditDate', 'CommunityOwnedDate', 'ParentId', 'ClosedDate', 'OwnerDisplayName', 'LastEditorDisplayName']
posts = pd.DataFrame(columns = columns_posts)

# %%
posts
# Out:
# Empty DataFrame
# Columns: [Id, PostTypeId, AcceptedAnswerId, CreaionDate, Score, ViewCount, Body, OwnerUserId, LasActivityDate, Title, Tags, AnswerCount, CommentCount, FavoriteCount, LastEditorUserId, LastEditDate, CommunityOwnedDate, ParentId, ClosedDate, OwnerDisplayName, LastEditorDisplayName]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# #### 12. Fill the new posts dataframe with the data you can get iterating through cursor (as seen in classes' Jupyter Notebook)

# %%
#for i, data in enumerate(cursor):
    #posts.loc[i] = data

# %%
posts = pd.read_csv('posts_table.csv')

# %%
posts.columns = columns_posts

# %%
posts.head()
# Out:
#    Id  PostTypeId  AcceptedAnswerId          CreaionDate  Score  ViewCount  \
# 0   1           1              15.0  2010-07-19 19:12:12     23     1278.0
# 1   2           1              59.0  2010-07-19 19:12:57     22     8198.0
# 2   3           1               5.0  2010-07-19 19:13:28     54     3613.0
# 3   4           1             135.0  2010-07-19 19:13:31     13     5224.0
# 4   5           2               NaN  2010-07-19 19:14:43     81        NaN
#
#                                                 Body  OwnerUserId  \
# 0  <p>How should I elicit prior distributions fro...          8.0
# 1  <p>In many different statistical methods there...         24.0
# 2  <p>What are some valuable Statistical Analysis...         18.0
# 3  <p>I have two groups of data.  Each with a dif...         23.0
# 4  <p>The R-project</p>\n\n<p><a href="http://www...         23.0
#
#        LasActivityDate                                              Title  \
# ...

# %% [markdown]
# #### 13. Rename Id column to postId and OwnerUserId to userId

# %%
posts = posts.rename(columns = {"Id": "postId", "OwnerUserId":"userId"})

# %%
posts.head()
# Out:
#    postId  PostTypeId  AcceptedAnswerId          CreaionDate  Score  \
# 0       1           1              15.0  2010-07-19 19:12:12     23
# 1       2           1              59.0  2010-07-19 19:12:57     22
# 2       3           1               5.0  2010-07-19 19:13:28     54
# 3       4           1             135.0  2010-07-19 19:13:31     13
# 4       5           2               NaN  2010-07-19 19:14:43     81
#
#    ViewCount                                               Body  userId  \
# 0     1278.0  <p>How should I elicit prior distributions fro...     8.0
# 1     8198.0  <p>In many different statistical methods there...    24.0
# 2     3613.0  <p>What are some valuable Statistical Analysis...    18.0
# 3     5224.0  <p>I have two groups of data.  Each with a dif...    23.0
# 4        NaN  <p>The R-project</p>\n\n<p><a href="http://www...    23.0
#
#        LasActivityDate                                              Title  \
# ...

# %% [markdown]
# # 14. Define new dataframes for users and posts with the following selected columns:
#     **users columns**: userId, Reputation,Views,UpVotes,DownVotes
#     **posts columns**: postId, Score,userID,ViewCount,CommentCount

# %%
users_1 = users[['userId','Reputation','Views','UpVotes','DownVotes']]
posts_1 = posts[['postId','Score','userId','ViewCount','CommentCount']]

# %%
users_1.head()
# Out:
#    userId  Reputation  Views  UpVotes  DownVotes
# 0       1           1      0     5007       1920
# 1       2         101     25        3          0
# 2       3         101     22       19          0
# 3       4         101     11        0          0
# 4       5        6792   1145      662          5

# %%
posts_1.head()
# Out:
#    postId  Score  userId  ViewCount  CommentCount
# 0       1     23     8.0     1278.0             1
# 1       2     22    24.0     8198.0             1
# 2       3     54    18.0     3613.0             4
# 3       4     13    23.0     5224.0             2
# 4       5     81    23.0        NaN             3

# %% [markdown]
# #### 15. Merge both dataframes, users and posts.
# You will need to make a [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.

# %%
users_m_posts = pd.merge(users_1, posts_1, left_index=True, right_index=True)

# %%
users_m_posts.head()
# Out:
#    userId_x  Reputation  Views  UpVotes  DownVotes  postId  Score  userId_y  \
# 0         1           1      0     5007       1920       1     23       8.0
# 1         2         101     25        3          0       2     22      24.0
# 2         3         101     22       19          0       3     54      18.0
# 3         4         101     11        0          0       4     13      23.0
# 4         5        6792   1145      662          5       5     81      23.0
#
#    ViewCount  CommentCount
# 0     1278.0             1
# 1     8198.0             1
# 2     3613.0             4
# 3     5224.0             2
# 4        0.0             3

# %% [markdown]
# #### 16. How many missing values do you have in your merged dataframe? On which columns?

# %%
#Null means missing. False is zero (take into account that value 0.0 is a number!)

users_m_posts.isnull().sum() #columns that have NaN/Null and how many Null values. Gives all columns
# Out:
# userId_x            0
# Reputation          0
# Views               0
# UpVotes             0
# DownVotes           0
# postId              0
# Score               0
# userId_y          759
# ViewCount       17162
# CommentCount        0
# dtype: int64

# %%
users_m_posts_null = users_m_posts.isnull().sum()

users_m_posts_null [users_m_posts_null > 0] #returns only those columns that have any Null value and how many
# Out:
# userId_y       759
# ViewCount    17162
# dtype: int64

# %%
list(users_m_posts_null [users_m_posts_null > 0].index) #areturns the columns ids only. puts it into a list
# Out:
# ['userId_y', 'ViewCount']

# %% [markdown]
# #### 17. You will need to make something with missing values.  Will you clean or filling them? Explain.
# **Remember** to check the results of your code before passing to the next step

# %%
users_m_posts.shape

#out of 28542 entries, 759 in userId_y and 17162 in ViewCount are Null.
# Out:
# (28542, 10)

# %%
#I'll start by filling Null values with 0.0
#(I assum that a Null Value for ViewCount means maybe that there were 0 views on that post.
#Also, I assume zero for a null value in userId_y (Id of the post?). Maybe I can say that 0.0 here means no Id was
#atributed to the post

users_m_posts[['userId_y', 'ViewCount']] = users_m_posts[['userId_y', 'ViewCount']].fillna(0)

#And find which entries have both 'userId_y' and 'ViewCount' equal to 0.0

both_zero = users_m_posts[(users_m_posts['userId_y']==0) & (users_m_posts['ViewCount']==0)]
both_zero.head(30)
# Out:
#      userId_x  Reputation  Views  UpVotes  DownVotes  postId  Score  userId_y  \
# 27         34         185     27       23          0      28      6       0.0
# 54         67         101      4        0          0      56     56       0.0
# 94        115         101      8        0          0     101     40       0.0
# 181       215        2496    384        5          0     193      6       0.0
# 195       230        1233    106      170          2     207     48       0.0
# 288       369          29      1        0          0     303      2       0.0
# 295       380         101      2        4          0     310      1       0.0
# 303       390         101      0        0          0     318      4       0.0
# 346       447        1422    173       20          0     368      2       0.0
# 432       583         101      0        0          0     457      4       0.0
# 476       648         101      0        0          0     502      5       0.0
# ...

# %%
both_zero.shape #there are 533 entries where both 'userId_y' and 'ViewCount' are equal to 0.0
# Out:
# (533, 10)

# %%
three_zero = users_m_posts[(users_m_posts['userId_y']==0) & (users_m_posts['ViewCount']==0) & (users_m_posts['Views']==0)]
three_zero.head(30)
# Out:
#       userId_x  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 303        390         101      0        0          0     318      4
# 432        583         101      0        0          0     457      4
# 476        648         101      0        0          0     502      5
# 599        822         101      0        0          0     628     16
# 608        833          21      0        0          0     640     12
# 666        928         101      0        0          0     705      4
# 696        971         101      0        0          0     737     45
# 756       1063         101      0        0          0     800      1
# 843       1180         101      0        1          0     889      1
# 879       1244         101      0        0          0     932      3
# 939       1322         101      0        0          0     999      3
# 1020      1462         101      0        0          0    1094      2
# 1027      1472         101      0        0          0    1102      0
# ...

# %%
three_zero.shape
# Out:
# (195, 10)

# %%
#I decided to drop the entries where 'userId_y', 'ViewCount' and 'Views' are equal to 0.0, as the 
#contributed content on the Stats Stack Exchange network from a user that doesn't have any view on the post plus 
# no Id on the post should be removed.

list_three_zero = list(three_zero.index)

users_m_posts_dropped = users_m_posts.drop(list_three_zero)

users_m_posts_dropped.head()
# Out:
#    userId_x  Reputation  Views  UpVotes  DownVotes  postId  Score  userId_y  \
# 0         1           1      0     5007       1920       1     23       8.0
# 1         2         101     25        3          0       2     22      24.0
# 2         3         101     22       19          0       3     54      18.0
# 3         4         101     11        0          0       4     13      23.0
# 4         5        6792   1145      662          5       5     81      23.0
#
#    ViewCount  CommentCount
# 0     1278.0             1
# 1     8198.0             1
# 2     3613.0             4
# 3     5224.0             2
# 4        0.0             3

# %% [markdown]
# #### 18. Adjust the data types in order to avoid future issues. Which ones should be changed?

# %%
users_m_posts_dropped['userId_x'].dtype #int
users_m_posts_dropped['Reputation'].dtype #int
users_m_posts_dropped['Views'].dtype #int
users_m_posts_dropped['UpVotes'].dtype #int
users_m_posts_dropped['DownVotes'].dtype #int
users_m_posts_dropped['postId'].dtype #int
users_m_posts_dropped['Score'].dtype #int
users_m_posts_dropped['userId_y'].dtype #float
users_m_posts_dropped['ViewCount'].dtype #float
users_m_posts_dropped['CommentCount'].dtype #int


#I will convert the last three columns to int type as it doesn't make sense to be float here
users_m_posts_dropped['userId_y'] = users_m_posts_dropped['userId_y'].astype('int')
users_m_posts_dropped['ViewCount'] = users_m_posts_dropped['ViewCount'].astype('int')
users_m_posts_dropped['CommentCount'] = users_m_posts_dropped['CommentCount'].astype('int')

users_m_posts_dropped['CommentCount'].dtype
# Out:
# dtype('int64')

# %%
#outliers to .csv doc

users_m_posts_dropped.to_csv('outliers.csv')
