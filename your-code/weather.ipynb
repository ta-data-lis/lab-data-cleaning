# %% [markdown]
# ## Global Historical Climatology Network Dataset
# Variables are stored in both rows and columns
# This dataset represents the daily weather records for a weather station (MX17004) in Mexico for five months in 2010.

# %%
import pandas as pd
import numpy as np

# %%
file = "../weather-raw.csv"
data = pd.read_csv(file, sep=",")
data.head(25)
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6  ...  \
# 0   MX17004  2010      1    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1   MX17004  2010      1    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2   MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN  ...
# 3   MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN  ...
# 4   MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN  ...
# 5   MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN  ...
# 6   MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7   MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8   MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9   MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10  MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11  MX17004  2010      6    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
print(data["id"].value_counts())
print(data["year"].value_counts())

# "id" and "year" are superfluous because they have constant values that will not change
data = data.drop(["id", "year"], axis=1)
data.head()
# Out:
# MX17004    22
# Name: id, dtype: int64
# 2010    22
# Name: year, dtype: int64
#    month element  d1    d2    d3  d4    d5  d6  d7  d8  ...  d22   d23  d24  \
# 0      1    tmax NaN   NaN   NaN NaN   NaN NaN NaN NaN  ...  NaN   NaN  NaN
# 1      1    tmin NaN   NaN   NaN NaN   NaN NaN NaN NaN  ...  NaN   NaN  NaN
# 2      2    tmax NaN  27.3  24.1 NaN   NaN NaN NaN NaN  ...  NaN  29.9  NaN
# 3      2    tmin NaN  14.4  14.4 NaN   NaN NaN NaN NaN  ...  NaN  10.7  NaN
# 4      3    tmax NaN   NaN   NaN NaN  32.1 NaN NaN NaN  ...  NaN   NaN  NaN
#
#    d25  d26  d27  d28  d29   d30  d31
# 0  NaN  NaN  NaN  NaN  NaN  27.8  NaN
# 1  NaN  NaN  NaN  NaN  NaN  14.5  NaN
# 2  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#
# [5 rows x 33 columns]

# %%
data.shape
# Out:
# (22, 33)

# %%
# the clean dataset should contain the columns [month, day, tmin, tmax]
#
# newcols = ["month", "day", "tmax", "tmin"]
# newvals = [(month,day,-1,-1) for month in range(1,13) for day in range(1,32)]
# data_clean = pd.DataFrame(np.array(newvals), columns=newcols)
# data_clean.head()
#
# then populate the clean dataset with values from the original
#
# for col in list(data.columns)[2:]:
#    index = 0
#    for row in list(data.index):
#        if index%2==0:  #tmax
#            #something
#        else:           #tmin
#            #something else
#        index += 1
#
#
#
# sample code for melt - causes loss of tmin/tmax data
# colnames=list(data.columns)
# new_ds = data.melt(id_vars=[('month', 'element')], value_vars=colnames[2:])
# new_ds.columns = ["month", "day", "value"]
# new_ds
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#      month  day  value
# 0      NaN   d1    NaN
# 1      NaN   d1    NaN
# 2      NaN   d1    NaN
# 3      NaN   d1    NaN
# 4      NaN   d1    NaN
# ..     ...  ...    ...
# 677    NaN  d31    NaN
# 678    NaN  d31    NaN
# 679    NaN  d31    NaN
# 680    NaN  d31    NaN
# 681    NaN  d31    NaN
#
# [682 rows x 3 columns]
