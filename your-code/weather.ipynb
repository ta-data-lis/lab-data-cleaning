# %% [markdown]
# ## Global Historical Climatology Network Dataset
# Variables are stored in both rows and columns
# This dataset represents the daily weather records for a weather station (MX17004) in Mexico for five months in 2010.

# %%
import pandas as pd

# %%
df_weather_raw = pd.read_csv('weather-raw.csv')

# %%
# Visualizing what we have.
# Simplest way of doing it for smaller sets of data...
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df_weather_raw)
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6    d7  \
# 0   MX17004  2010      1    tmax   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   MX17004  2010      1    tmin   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN   NaN
# 3   MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN   NaN
# 4   MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN   NaN
# 5   MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN   NaN
# 6   MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 7   MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 8   MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 9   MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 10  MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 11  MX17004  2010      6    tmin   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 12  MX17004  2010      7    tmax   NaN   NaN  28.6   NaN   NaN   NaN   NaN
# 13  MX17004  2010      7    tmin   NaN   NaN  17.5   NaN   NaN   NaN   NaN
# 14  MX17004  2010      8    tmax   NaN   NaN   NaN   NaN  29.6   NaN   NaN
# 15  MX17004  2010      8    tmin   NaN   NaN   NaN   NaN  15.8   NaN   NaN
# 16  MX17004  2010     10    tmax   NaN   NaN   NaN   NaN  27.0   NaN  28.1
# 17  MX17004  2010     10    tmin   NaN   NaN   NaN   NaN  14.0   NaN  12.9
# 18  MX17004  2010     11    tmax   NaN  31.3   NaN  27.2  26.3   NaN   NaN
# 19  MX17004  2010     11    tmin   NaN  16.3   NaN  12.0   7.9   NaN   NaN
# 20  MX17004  2010     12    tmax  29.9   NaN   NaN   NaN   NaN  27.8   NaN
# 21  MX17004  2010     12    tmin  13.8   NaN   NaN   NaN   NaN  10.5   NaN
#
#       d8  d9   d10   d11  d12   d13   d14   d15   d16   d17  d18  d19  d20  \
# 0    NaN NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 1    NaN NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 2    NaN NaN   NaN  29.7  NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 3    NaN NaN   NaN  13.4  NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 4    NaN NaN  34.5   NaN  NaN   NaN   NaN   NaN  31.1   NaN  NaN  NaN  NaN
# 5    NaN NaN  16.8   NaN  NaN   NaN   NaN   NaN  17.6   NaN  NaN  NaN  NaN
# 6    NaN NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 7    NaN NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 8    NaN NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 9    NaN NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 10   NaN NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN  28.0  NaN  NaN  NaN
# 11   NaN NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN  17.5  NaN  NaN  NaN
# 12   NaN NaN   NaN   NaN  NaN   NaN  29.9   NaN   NaN   NaN  NaN  NaN  NaN
# 13   NaN NaN   NaN   NaN  NaN   NaN  16.5   NaN   NaN   NaN  NaN  NaN  NaN
# 14  29.0 NaN   NaN   NaN  NaN  29.8   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 15  17.3 NaN   NaN   NaN  NaN  16.5   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 16   NaN NaN   NaN   NaN  NaN   NaN  29.5  28.7   NaN   NaN  NaN  NaN  NaN
# 17   NaN NaN   NaN   NaN  NaN   NaN  13.0  10.5   NaN   NaN  NaN  NaN  NaN
# 18   NaN NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 19   NaN NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 20   NaN NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 21   NaN NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
#
#     d21  d22   d23  d24   d25   d26   d27   d28   d29   d30   d31
# 0   NaN  NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN  27.8   NaN
# 1   NaN  NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN  14.5   NaN
# 2   NaN  NaN  29.9  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN  NaN  10.7  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN  NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5   NaN  NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6   NaN  NaN   NaN  NaN   NaN   NaN  36.3   NaN   NaN   NaN   NaN
# 7   NaN  NaN   NaN  NaN   NaN   NaN  16.7   NaN   NaN   NaN   NaN
# 8   NaN  NaN   NaN  NaN   NaN   NaN  33.2   NaN   NaN   NaN   NaN
# 9   NaN  NaN   NaN  NaN   NaN   NaN  18.2   NaN   NaN   NaN   NaN
# 10  NaN  NaN   NaN  NaN   NaN   NaN   NaN   NaN  30.1   NaN   NaN
# 11  NaN  NaN   NaN  NaN   NaN   NaN   NaN   NaN  18.0   NaN   NaN
# 12  NaN  NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 13  NaN  NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 14  NaN  NaN  26.4  NaN  29.7   NaN   NaN   NaN  28.0   NaN  25.4
# 15  NaN  NaN  15.0  NaN  15.6   NaN   NaN   NaN  15.3   NaN  15.4
# 16  NaN  NaN   NaN  NaN   NaN   NaN   NaN  31.2   NaN   NaN   NaN
# 17  NaN  NaN   NaN  NaN   NaN   NaN   NaN  15.0   NaN   NaN   NaN
# 18  NaN  NaN   NaN  NaN   NaN  28.1  27.7   NaN   NaN   NaN   NaN
# 19  NaN  NaN   NaN  NaN   NaN  12.1  14.2   NaN   NaN   NaN   NaN
# 20  NaN  NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 21  NaN  NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN

# %%
#Given that id and year are always the same, there is no purpose in keeping them when doing transformations.
#One could have the same reasoning if it was considered that we have two databases, one with maximum and another with minumum temperatures.
#Below, I will be dropping the constant columns and splitting into two smallar data frames.

df_weather_max = df_weather_raw[(df_weather_raw['element']=='tmax')]
df_weather_min = df_weather_raw[(df_weather_raw['element']=='tmax')]

df_weather_max = df_weather_max.drop(['element', 'id', 'year'], axis=1)
df_weather_min = df_weather_min.drop(['element', 'id', 'year'], axis=1)

# %%
# Using the .melt function we "unpivot" the data for both our data frames.
my_cols_list_a = ['month']
my_cols_list_b = [i for i in list(df_weather_max.columns) if i not in my_cols_list_a]
df_weather_max_melted = df_weather_max.melt(id_vars = my_cols_list_a, value_vars = my_cols_list_b)
df_weather_min_melted = df_weather_min.melt(id_vars = my_cols_list_a, value_vars = my_cols_list_b)

# We add back the variables we dropped and append the databases
df_weather_max_melted['element']='tmax'
df_weather_min_melted['element']='tmin'
df_weather_appended = df_weather_max_melted.append(df_weather_min_melted)
df_weather_appended['id'] = 'MX17004'
df_weather_appended['year'] = 2010

df_weather_final = df_weather_appended

# The letter d before the variable seems to be meaningless and prevents us from having it as an integer.
df_weather_final['variable'] = df_weather_final['variable'].str.replace('d', '')
df_weather_final['variable'] = df_weather_final['variable'].astype('int')

# For completeness I guess we can add the d we removed as a different column.
df_weather_final['variable_letter'] = 'd'

# %%
# The row with NaN for the value columns are not useful and with this layout they are simple to drop.
df_weather_final = df_weather_final.dropna(axis = 0)

# %%
# Finally, to make it more readble we reorder and sort
df_weather_final = df_weather_final[['id', 'year', 'variable_letter','variable', 'element', 'month', 'value']]
df_weather_final = df_weather_final.sort_values('variable')
df_weather_final = df_weather_final.reset_index()
df_weather_final = df_weather_final.drop(['index'], axis=1)

# %%
# Final check.
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df_weather_final)
# Out:
#          id  year variable_letter  variable element  month  value
# 0   MX17004  2010               d         1    tmax     12   29.9
# 1   MX17004  2010               d         1    tmin     12   29.9
# 2   MX17004  2010               d         2    tmax     11   31.3
# 3   MX17004  2010               d         2    tmax      2   27.3
# 4   MX17004  2010               d         2    tmin      2   27.3
# 5   MX17004  2010               d         2    tmin     11   31.3
# 6   MX17004  2010               d         3    tmax      2   24.1
# 7   MX17004  2010               d         3    tmax      7   28.6
# 8   MX17004  2010               d         3    tmin      7   28.6
# 9   MX17004  2010               d         3    tmin      2   24.1
# 10  MX17004  2010               d         4    tmax     11   27.2
# 11  MX17004  2010               d         4    tmin     11   27.2
# 12  MX17004  2010               d         5    tmax     10   27.0
# 13  MX17004  2010               d         5    tmax      8   29.6
# 14  MX17004  2010               d         5    tmin     11   26.3
# 15  MX17004  2010               d         5    tmin     10   27.0
# 16  MX17004  2010               d         5    tmin      8   29.6
# 17  MX17004  2010               d         5    tmin      3   32.1
# 18  MX17004  2010               d         5    tmax     11   26.3
# 19  MX17004  2010               d         5    tmax      3   32.1
# 20  MX17004  2010               d         6    tmax     12   27.8
# 21  MX17004  2010               d         6    tmin     12   27.8
# 22  MX17004  2010               d         7    tmax     10   28.1
# 23  MX17004  2010               d         7    tmin     10   28.1
# 24  MX17004  2010               d         8    tmin      8   29.0
# 25  MX17004  2010               d         8    tmax      8   29.0
# 26  MX17004  2010               d        10    tmin      3   34.5
# 27  MX17004  2010               d        10    tmax      3   34.5
# 28  MX17004  2010               d        11    tmin      2   29.7
# 29  MX17004  2010               d        11    tmax      2   29.7
# 30  MX17004  2010               d        13    tmin      8   29.8
# 31  MX17004  2010               d        13    tmax      8   29.8
# 32  MX17004  2010               d        14    tmin     10   29.5
# 33  MX17004  2010               d        14    tmin      7   29.9
# 34  MX17004  2010               d        14    tmax      7   29.9
# 35  MX17004  2010               d        14    tmax     10   29.5
# 36  MX17004  2010               d        15    tmin     10   28.7
# 37  MX17004  2010               d        15    tmax     10   28.7
# 38  MX17004  2010               d        16    tmin      3   31.1
# 39  MX17004  2010               d        16    tmax      3   31.1
# 40  MX17004  2010               d        17    tmin      6   28.0
# 41  MX17004  2010               d        17    tmax      6   28.0
# 42  MX17004  2010               d        23    tmax      2   29.9
# 43  MX17004  2010               d        23    tmax      8   26.4
# 44  MX17004  2010               d        23    tmin      8   26.4
# 45  MX17004  2010               d        23    tmin      2   29.9
# 46  MX17004  2010               d        25    tmin      8   29.7
# 47  MX17004  2010               d        25    tmax      8   29.7
# 48  MX17004  2010               d        26    tmin     11   28.1
# 49  MX17004  2010               d        26    tmax     11   28.1
# 50  MX17004  2010               d        27    tmin      5   33.2
# 51  MX17004  2010               d        27    tmin     11   27.7
# 52  MX17004  2010               d        27    tmax     11   27.7
# 53  MX17004  2010               d        27    tmax      5   33.2
# 54  MX17004  2010               d        27    tmax      4   36.3
# 55  MX17004  2010               d        27    tmin      4   36.3
# 56  MX17004  2010               d        28    tmin     10   31.2
# 57  MX17004  2010               d        28    tmax     10   31.2
# 58  MX17004  2010               d        29    tmin      8   28.0
# 59  MX17004  2010               d        29    tmin      6   30.1
# 60  MX17004  2010               d        29    tmax      8   28.0
# 61  MX17004  2010               d        29    tmax      6   30.1
# 62  MX17004  2010               d        30    tmin      1   27.8
# 63  MX17004  2010               d        30    tmax      1   27.8
# 64  MX17004  2010               d        31    tmax      8   25.4
# 65  MX17004  2010               d        31    tmin      8   25.4
