# %% [markdown]
# ## Global Historical Climatology Network Dataset
# Variables are stored in both rows and columns
# This dataset represents the daily weather records for a weather station (MX17004) in Mexico for five months in 2010.

# %%
import pandas as pd

# %%
df = pd.read_csv('../weather-raw.csv')
df
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6  ...  \
# 0   MX17004  2010      1    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1   MX17004  2010      1    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2   MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN  ...
# 3   MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN  ...
# 4   MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN  ...
# 5   MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN  ...
# 6   MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7   MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8   MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9   MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10  MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11  MX17004  2010      6    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
# First let's put every single 'name' in each column 'd1', ..., 'd31' to a row. Each of these values appear twice for  each
# month.
reshaped_df = df.melt(id_vars= ['month', 'element'], value_vars= list(df.columns[4:]))
reshaped_df
# Out:
#      month element variable  value
# 0        1    tmax       d1    NaN
# 1        1    tmin       d1    NaN
# 2        2    tmax       d1    NaN
# 3        2    tmin       d1    NaN
# 4        3    tmax       d1    NaN
# ..     ...     ...      ...    ...
# 677     10    tmin      d31    NaN
# 678     11    tmax      d31    NaN
# 679     11    tmin      d31    NaN
# 680     12    tmax      d31    NaN
# 681     12    tmin      d31    NaN
#
# [682 rows x 4 columns]

# %%
# Now let's drop each null value in column 'value'
reshaped_df = reshaped_df.dropna(subset=['value'])
reshaped_df
# Out:
#      month element variable  value
# 20      12    tmax       d1   29.9
# 21      12    tmin       d1   13.8
# 24       2    tmax       d2   27.3
# 25       2    tmin       d2   14.4
# 40      11    tmax       d2   31.3
# ..     ...     ...      ...    ...
# 631      8    tmin      d29   15.3
# 638      1    tmax      d30   27.8
# 639      1    tmin      d30   14.5
# 674      8    tmax      d31   25.4
# 675      8    tmin      d31   15.4
#
# [66 rows x 4 columns]

# %%
# Finally let's aggregate the maximum and minimum value per month
reshaped_df = reshaped_df.pivot_table(index='month', values= 'value', aggfunc=['max', 'min'])
reshaped_df
# Out:
#         max   min
#       value value
# month
# 1      27.8  14.5
# 2      29.9  10.7
# 3      34.5  14.2
# 4      36.3  16.7
# 5      33.2  18.2
# 6      30.1  17.5
# 7      29.9  16.5
# 8      29.8  15.0
# 10     31.2  10.5
# 11     31.3   7.9
# 12     29.9  10.5
