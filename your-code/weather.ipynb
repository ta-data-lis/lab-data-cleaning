# %% [markdown]
# ## Global Historical Climatology Network Dataset
# Variables are stored in both rows and columns
# This dataset represents the daily weather records for a weather station (MX17004) in Mexico for five months in 2010.

# %%
# importing libraries
import pandas as pd
import numpy as np

# %%
#missing_values = ["n/a", "na", "--"]
#df = pd.read_csv("../weather-raw.csv", na_values = missing_values)
ds = pd.read_csv('../weather-raw.csv')
ds.head(3)
# Out:
#         id  year  month element  d1    d2    d3  d4  d5  d6  ...  d22   d23  \
# 0  MX17004  2010      1    tmax NaN   NaN   NaN NaN NaN NaN  ...  NaN   NaN
# 1  MX17004  2010      1    tmin NaN   NaN   NaN NaN NaN NaN  ...  NaN   NaN
# 2  MX17004  2010      2    tmax NaN  27.3  24.1 NaN NaN NaN  ...  NaN  29.9
#
#    d24  d25  d26  d27  d28  d29   d30  d31
# 0  NaN  NaN  NaN  NaN  NaN  NaN  27.8  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  14.5  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#
# [3 rows x 35 columns]

# %%
ds.shape # represents sample(row) and features(columns) of sample
# one month must be missing -> only 22 rows (september is missing)
# probably missing values for every other month because they only have 30 days
# coulums are (weather station, year, month, average, day 1 to day 31)
# Out:
# (22, 35)

# %%
#ds.describe()

# %%
ds = ds.rename(columns={"id": "WeatherStation", "element": "average",})

# %%
dsnull = ds.isnull().sum()
print(dsnull)
# Out:
# WeatherStation     0
# year               0
# month              0
# average            0
# d1                20
# d2                18
# d3                18
# d4                20
# d5                14
# d6                20
# d7                20
# d8                20
# d9                22
# d10               20
# d11               20
# d12               22
# d13               20
# d14               18
# d15               20
# d16               20
# d17               20
# d18               22
# d19               22
# d20               22
# d21               22
# d22               22
# d23               18
# d24               22
# d25               20
# d26               20
# d27               16
# d28               20
# d29               18
# d30               20
# d31               20
# dtype: int64

# %%
zero_values = ds[ds == 0.0].count() #to check how many zeros in one row
# print(zero_values)
# every row has at least one value

# %%
#ds.replace(missing values, "-")
ds[list(ds.columns)].fillna("-")
print(ds)
# Out:
#    WeatherStation  year  month average    d1    d2    d3    d4    d5    d6  \
# 0         MX17004  2010      1    tmax   NaN   NaN   NaN   NaN   NaN   NaN
# 1         MX17004  2010      1    tmin   NaN   NaN   NaN   NaN   NaN   NaN
# 2         MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN
# 3         MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN
# 4         MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN
# 5         MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN
# 6         MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN
# 7         MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN
# 8         MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN
# 9         MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN
# 10        MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
ds
# Out:
#    WeatherStation  year  month average    d1    d2    d3    d4    d5    d6  \
# 0         MX17004  2010      1    tmax   NaN   NaN   NaN   NaN   NaN   NaN
# 1         MX17004  2010      1    tmin   NaN   NaN   NaN   NaN   NaN   NaN
# 2         MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN
# 3         MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN
# 4         MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN
# 5         MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN
# 6         MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN
# 7         MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN
# 8         MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN
# 9         MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN
# 10        MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
# goal = column tmx and tmin
# can use pd.melt or weather.melt
weather_melt = pd.melt(
    ds,
    id_vars = ['WeatherStation', 'year', 'month', 'average'],
    var_name = 'day',
    value_name = 'temp'
)

# %%
weather_melt
# Out:
#     WeatherStation  year  month average  day  temp
# 0          MX17004  2010      1    tmax   d1   NaN
# 1          MX17004  2010      1    tmin   d1   NaN
# 2          MX17004  2010      2    tmax   d1   NaN
# 3          MX17004  2010      2    tmin   d1   NaN
# 4          MX17004  2010      3    tmax   d1   NaN
# ..             ...   ...    ...     ...  ...   ...
# 677        MX17004  2010     10    tmin  d31   NaN
# 678        MX17004  2010     11    tmax  d31   NaN
# 679        MX17004  2010     11    tmin  d31   NaN
# 680        MX17004  2010     12    tmax  d31   NaN
# 681        MX17004  2010     12    tmin  d31   NaN
#
# [682 rows x 6 columns]

# %%
weather_tidy = weather_melt.pivot_table(
    index = ['WeatherStation', 'year', 'month', 'average'],
    columns='average', 
    values='temp',
    dropna=True    # does not work
)

# %%
weather_tidy1 = weather_tidy[list(weather_tidy.columns)].fillna("-")
weather_tidy1
# Out:
# average                               tmax     tmin
# WeatherStation year month average
# MX17004        2010 1     tmax        27.8        -
#                           tmin           -     14.5
#                     2     tmax       27.75        -
#                           tmin           -   13.225
#                     3     tmax     32.5667        -
#                           tmin           -     16.2
#                     4     tmax        36.3        -
#                           tmin           -     16.7
#                     5     tmax        33.2        -
#                           tmin           -     18.2
#                     6     tmax       29.05        -
#                           tmin           -    17.75
#                     7     tmax       29.25        -
#                           tmin           -       17
#                     8     tmax     28.2714        -
#                           tmin           -  15.8429
# ...

# %%
weather_tidy1[list(weather_tidy.columns)].fillna("-").reset_index()
# Out:
# average WeatherStation  year  month average     tmax     tmin
# 0              MX17004  2010      1    tmax     27.8        -
# 1              MX17004  2010      1    tmin        -     14.5
# 2              MX17004  2010      2    tmax    27.75        -
# 3              MX17004  2010      2    tmin        -   13.225
# 4              MX17004  2010      3    tmax  32.5667        -
# 5              MX17004  2010      3    tmin        -     16.2
# 6              MX17004  2010      4    tmax     36.3        -
# 7              MX17004  2010      4    tmin        -     16.7
# 8              MX17004  2010      5    tmax     33.2        -
# 9              MX17004  2010      5    tmin        -     18.2
# 10             MX17004  2010      6    tmax    29.05        -
# 11             MX17004  2010      6    tmin        -    17.75
# 12             MX17004  2010      7    tmax    29.25        -
# 13             MX17004  2010      7    tmin        -       17
# ...
