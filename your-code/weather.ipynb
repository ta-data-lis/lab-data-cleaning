# %% [markdown]
# ## Global Historical Climatology Network Dataset
# Variables are stored in both rows and columns
# This dataset represents the daily weather records for a weather station (MX17004) in Mexico for five months in 2010.

# %%
# The goal of this additional challenge is to get the most tidy dataset you are able to produce.
# **Hint:Variables are stored in both rows and columns.**

# To accomplish this challenge, you will need to do some research on tidying and melt&pivot.
# Feel free to reference any resources you consider appropiate.

# %%
import pandas as pd
weather_df= pd.read_csv(("C:\\Users\\Zoe Mercury\\Documents\\GitHub\\Week 2\\lab-data-cleaning\\weather-raw.csv"))
weather_df
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6  ...  \
# 0   MX17004  2010      1    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1   MX17004  2010      1    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2   MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN  ...
# 3   MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN  ...
# 4   MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN  ...
# 5   MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN  ...
# 6   MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7   MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8   MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9   MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10  MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11  MX17004  2010      6    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
weather= weather_df.drop(["year","month"], axis=1)
weather
# Out:
#          id element    d1    d2    d3    d4    d5    d6    d7    d8  ...  d22  \
# 0   MX17004    tmax   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  NaN
# 1   MX17004    tmin   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  NaN
# 2   MX17004    tmax   NaN  27.3  24.1   NaN   NaN   NaN   NaN   NaN  ...  NaN
# 3   MX17004    tmin   NaN  14.4  14.4   NaN   NaN   NaN   NaN   NaN  ...  NaN
# 4   MX17004    tmax   NaN   NaN   NaN   NaN  32.1   NaN   NaN   NaN  ...  NaN
# 5   MX17004    tmin   NaN   NaN   NaN   NaN  14.2   NaN   NaN   NaN  ...  NaN
# 6   MX17004    tmax   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  NaN
# 7   MX17004    tmin   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  NaN
# 8   MX17004    tmax   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  NaN
# 9   MX17004    tmin   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  NaN
# 10  MX17004    tmax   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  NaN
# ...

# %%
weather_df['Temperature']= weather.apply("mean", axis=1)

# %%
weather_df.drop(["d1","d2","d3","d4","d5","d6","d7"], axis=1, inplace=True)

# %%
weather_df.drop(["d8","d9","d10","d11","d12","d13","d14","d15","d16","d17","d18","d19","d20"], axis=1, inplace=True)

# %%
weather_df.drop(["d21","d22","d23","d24","d25","d26","d27","d28","d29","d30","d31"], axis=1, inplace=True)

# %%
weather_df
# Out:
#          id  year  month element  Temperature
# 0   MX17004  2010      1    tmax    27.800000
# 1   MX17004  2010      1    tmin    14.500000
# 2   MX17004  2010      2    tmax    27.750000
# 3   MX17004  2010      2    tmin    13.225000
# 4   MX17004  2010      3    tmax    32.566667
# 5   MX17004  2010      3    tmin    16.200000
# 6   MX17004  2010      4    tmax    36.300000
# 7   MX17004  2010      4    tmin    16.700000
# 8   MX17004  2010      5    tmax    33.200000
# 9   MX17004  2010      5    tmin    18.200000
# 10  MX17004  2010      6    tmax    29.050000
# 11  MX17004  2010      6    tmin    17.750000
# 12  MX17004  2010      7    tmax    29.250000
# 13  MX17004  2010      7    tmin    17.000000
# 14  MX17004  2010      8    tmax    28.271429
# 15  MX17004  2010      8    tmin    15.842857
# 16  MX17004  2010     10    tmax    28.900000
# 17  MX17004  2010     10    tmin    13.080000
# 18  MX17004  2010     11    tmax    28.120000
# ...

# %%
weather_df.groupby(by=["month"]).mean()
#This table shows us the average temperature per month
# Out:
#        year  Temperature
# month
# 1      2010    21.150000
# 2      2010    20.487500
# 3      2010    24.383333
# 4      2010    26.500000
# 5      2010    25.700000
# 6      2010    23.400000
# 7      2010    23.125000
# 8      2010    22.057143
# 10     2010    20.990000
# 11     2010    20.310000
# 12     2010    20.500000
