# %% [markdown]
# ## Global Historical Climatology Network Dataset
# Variables are stored in both rows and columns
# This dataset represents the daily weather records for a weather station (MX17004) in Mexico for five months in 2010.

# %%
#Bonus Question: Create a dataframe with the outliers you have identified in the dataframe and
#export it to a csv file in your-code folder.

# %% [markdown]
# This is not finish. I will come back on this after.
# I also check this with Filipe.

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\beatr\\Documents\\Beatriz\\Ironhack\\lab-data-cleaning\\weather-raw.csv")
df.head()
# Out:
#         id  year  month element  d1    d2    d3  d4    d5  d6  ...  d22   d23  \
# 0  MX17004  2010      1    tmax NaN   NaN   NaN NaN   NaN NaN  ...  NaN   NaN
# 1  MX17004  2010      1    tmin NaN   NaN   NaN NaN   NaN NaN  ...  NaN   NaN
# 2  MX17004  2010      2    tmax NaN  27.3  24.1 NaN   NaN NaN  ...  NaN  29.9
# 3  MX17004  2010      2    tmin NaN  14.4  14.4 NaN   NaN NaN  ...  NaN  10.7
# 4  MX17004  2010      3    tmax NaN   NaN   NaN NaN  32.1 NaN  ...  NaN   NaN
#
#    d24  d25  d26  d27  d28  d29   d30  d31
# 0  NaN  NaN  NaN  NaN  NaN  NaN  27.8  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  14.5  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#
# [5 rows x 35 columns]

# %%
df.drop(columns = ["year", "month"], axis = 1, inplace = True)
df.head()
# Out:
#         id element  d1    d2    d3  d4    d5  d6  d7  d8  ...  d22   d23  d24  \
# 0  MX17004    tmax NaN   NaN   NaN NaN   NaN NaN NaN NaN  ...  NaN   NaN  NaN
# 1  MX17004    tmin NaN   NaN   NaN NaN   NaN NaN NaN NaN  ...  NaN   NaN  NaN
# 2  MX17004    tmax NaN  27.3  24.1 NaN   NaN NaN NaN NaN  ...  NaN  29.9  NaN
# 3  MX17004    tmin NaN  14.4  14.4 NaN   NaN NaN NaN NaN  ...  NaN  10.7  NaN
# 4  MX17004    tmax NaN   NaN   NaN NaN  32.1 NaN NaN NaN  ...  NaN   NaN  NaN
#
#    d25  d26  d27  d28  d29   d30  d31
# 0  NaN  NaN  NaN  NaN  NaN  27.8  NaN
# 1  NaN  NaN  NaN  NaN  NaN  14.5  NaN
# 2  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#
# [5 rows x 33 columns]

# %%
#Transpose to get the info:
stats = df.describe().transpose()

#Add the column IQR and the calculation of the IQR
stats["IQR"] = stats["75%"] - stats["25%"]
stats

#Add 1.5 * IQR to the third quartile. Any number that is greater than this is a suspected outlier
#Subtract 1.5 * IQR to the first quartile. Any number that is lower than this is a suspected outlier.

#Create bothe Upper and Lower Bound:
stats["UpperBound"] = ((stats["75%"]) + (1.5 * stats["IQR"]))
stats["LowerBound"] = ((stats["25%"]) - (1.5 * stats["IQR"]))
stats

#OUTPUT: are the columns that have outliers
#stats[(stats["UpperBound"] < stats["max"]) | (stats["LowerBound"] > stats["min"])]
# Out:
#      count       mean        std   min     25%    50%     75%   max     IQR  \
# d1     2.0  21.850000  11.384419  13.8  17.825  21.85  25.875  29.9   8.050
# d2     4.0  22.325000   8.254443  14.4  15.825  21.80  28.300  31.3  12.475
# d3     4.0  21.150000   6.405466  14.4  16.725  20.80  25.225  28.6   8.500
# d4     2.0  19.600000  10.748023  12.0  15.800  19.60  23.400  27.2   7.600
# d5     8.0  20.862500   8.904243   7.9  14.150  21.05  27.650  32.1  13.500
# d6     2.0  19.150000  12.232947  10.5  14.825  19.15  23.475  27.8   8.650
# d7     2.0  20.500000  10.748023  12.9  16.700  20.50  24.300  28.1   7.600
# d8     2.0  23.150000   8.273149  17.3  20.225  23.15  26.075  29.0   5.850
# d9     0.0        NaN        NaN   NaN     NaN    NaN     NaN   NaN     NaN
# d10    2.0  25.650000  12.515790  16.8  21.225  25.65  30.075  34.5   8.850
# d11    2.0  21.550000  11.525841  13.4  17.475  21.55  25.625  29.7   8.150
# ...
